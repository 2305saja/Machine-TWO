# %% [markdown]
# ##1. Dimensionality Reduction##

# %%
import pandas as pd
Card_Data=pd.read_csv('creditcard.csv')
Card_Data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
Card_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19898 entries, 0 to 19897
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    19898 non-null  int64
#  1   V1      19898 non-null  float64
#  2   V2      19898 non-null  float64
#  3   V3      19898 non-null  float64
#  4   V4      19898 non-null  float64
#  5   V5      19898 non-null  float64
#  6   V6      19898 non-null  float64
#  7   V7      19898 non-null  float64
#  8   V8      19898 non-null  float64
#  9   V9      19898 non-null  float64
#  10  V10     19898 non-null  float64
#  11  V11     19897 non-null  float64
#  12  V12     19897 non-null  float64
#  13  V13     19897 non-null  float64
#  14  V14     19897 non-null  float64
#  15  V15     19897 non-null  float64
#  16  V16     19897 non-null  float64
#  17  V17     19897 non-null  float64
#  18  V18     19897 non-null  float64
#  19  V19     19897 non-null  float64
#  20  V20     19897 non-null  float64
#  21  V21     19897 non-null  float64
#  22  V22     19897 non-null  float64
#  23  V23     19897 non-null  float64
#  24  V24     19897 non-null  float64
#  25  V25     19897 non-null  float64
#  26  V26     19897 non-null  float64
#  27  V27     19897 non-null  float64
#  28  V28     19897 non-null  float64
#  29  Amount  19897 non-null  float64
#  30  Class   19897 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 4.7 MB

# %%
Card_Data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  19898.000000  19898.000000  19898.000000  19898.000000  19898.000000
# mean   15492.416374     -0.244326      0.242420      0.745774      0.277011
# std    10512.066686      1.889986      1.527342      1.767726      1.466218
# min        0.000000    -30.552380    -40.978852    -31.103685     -5.172595
# 25%     4536.250000     -0.959632     -0.329008      0.309235     -0.636713
# 50%    14796.000000     -0.302521      0.220079      0.898672      0.224608
# 75%    26220.500000      1.164473      0.870117      1.532922      1.142143
# max    30633.000000      1.960497     16.713389      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  19898.000000  19898.000000  19898.000000  19898.000000  19898.000000
# mean      -0.163264      0.092881     -0.145279      0.022237      0.636382
# std        1.430821      1.331029      1.338260      1.346813      1.278839
# min      -32.092129    -23.496714    -26.548144    -41.484823     -7.175097
# 25%       -0.745156     -0.657306     -0.599403     -0.171779     -0.209565
# 50%       -0.199377     -0.175434     -0.072254      0.023822      0.620176
# 75%        0.341367      0.486735      0.448572      0.279960      1.409142
# max       34.099309     21.393069     34.303177     20.007208     10.392889
#
#        ...           V21           V22           V23           V24  \
# count  ...  19897.000000  19897.000000  19897.000000  19897.000000
# mean   ...     -0.047949     -0.146461     -0.038093      0.010678
# std    ...      0.828385      0.637567      0.520683      0.591180
# min    ...    -20.262054     -8.593642    -26.751119     -2.728650
# 25%    ...     -0.259497     -0.563992     -0.174213     -0.333314
# 50%    ...     -0.115398     -0.118803     -0.046994      0.061181
# 75%    ...      0.049521      0.254057      0.073666      0.398549
# max    ...     22.614889      5.805795     13.876221      3.695503
#
#                 V25           V26           V27           V28        Amount  \
# count  19897.000000  19897.000000  19897.000000  19897.000000  19897.000000
# mean       0.122924      0.033127      0.014454      0.007312     70.271100
# std        0.437675      0.530315      0.393002      0.244372    205.363789
# min       -7.495741     -1.338556     -8.567638     -3.575312      0.000000
# 25%       -0.138325     -0.341917     -0.069146     -0.010879      5.750000
# 50%        0.160495     -0.036546      0.003868      0.019083     16.000000
# 75%        0.400713      0.332729      0.096281      0.077551     59.980000
# max        5.525093      3.517346      8.254376      4.860769   7879.420000
#
#               Class
# count  19897.000000
# mean       0.004272
# std        0.065222
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
Card_Data['Amount_Ratio'] = Card_Data['Amount'] / Card_Data['Amount'].mean()
Card_Data['Hour'] = (Card_Data['Time'] // 3600) % 24
Card_Data.drop(['Amount','Time'],inplace=True,axis=1)

# %%
Missing_Data=Card_Data.isnull().sum()
Missing_Data>0
# Out:
# V1              False
# V2              False
# V3              False
# V4              False
# V5              False
# V6              False
# V7              False
# V8              False
# V9              False
# V10             False
# V11              True
# V12              True
# V13              True
# V14              True
# V15              True
# V16              True
# V17              True
# V18              True
# V19              True
# V20              True
# V21              True
# V22              True
# V23              True
# V24              True
# V25              True
# V26              True
# V27              True
# V28              True
# Class            True
# Amount_Ratio     True
# Hour            False
# dtype: bool

# %%
import matplotlib.pyplot as plt
Card_Data.hist(bins=50, figsize=(12, 10),color='pink')
plt.suptitle("Feature Distributions", fontsize=16)
plt.subplots_adjust(hspace=0.4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
from sklearn.impute import SimpleImputer
import numpy as np
Continuous_Columns = [ 'V5', 'V6','V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14',
                       'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22',
                       'V23','V24', 'V25', 'V26', 'V27', 'V28','Class','Amount_Ratio']
Carde_imputed = SimpleImputer(missing_values=np.nan, strategy="mean")

Card_Data[Continuous_Columns]= Carde_imputed.fit_transform(Card_Data[Continuous_Columns])
Card_Data
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0     -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1      1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# ...         ...       ...       ...       ...       ...       ...       ...
# 19893 -0.377215  0.973528  1.647077  0.732439  0.024728 -0.541379  0.828488
# 19894  1.209281  0.078793  0.061820  0.593730 -0.235772 -0.448524 -0.141196
# 19895  1.286596 -1.450336  0.814530 -1.308949 -2.055209 -0.592064 -1.317286
# 19896 -0.488090  1.018448  0.670593 -0.245462  0.828347 -0.233102  0.662586
# 19897 -2.609841  2.479357  0.763844  0.044509 -0.645716  0.762867 -1.626415
#
#              V8        V9       V10  ...       V22       V23       V24  \
# 0      0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928
# 1      0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846
# 2      0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281
# 3      0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575
# 4     -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267
# ...         ...       ...       ...  ...       ...       ...       ...
# 19893 -0.060740 -0.725148 -0.450153  ...  0.685913 -0.107687  0.631740
# 19894  0.089236  0.411825 -0.263041  ... -0.984051  0.130401 -0.390756
# 19895  0.032386 -1.720017  1.589335  ...  0.262534 -0.045112  0.515660
# 19896 -0.040028 -0.279439 -0.402822  ... -0.902035 -0.050171 -1.060827
# 19897 -7.617854  1.399746  1.000000  ... -0.146461 -0.038093  0.010678
#
#             V25       V26       V27       V28     Class  Amount_Ratio  Hour
# 0      0.128539 -0.189115  0.133558 -0.021053  0.000000      2.129183     0
# 1      0.167170  0.125895 -0.008983  0.014724  0.000000      0.038280     0
# 2     -0.327642 -0.139097 -0.055353 -0.059752  0.000000      5.388559     0
# 3      0.647376 -0.221929  0.062723  0.061458  0.000000      1.757479     0
# 4     -0.206010  0.502292  0.219422  0.215153  0.000000      0.996000     0
# ...         ...       ...       ...       ...       ...           ...   ...
# 19893  0.126366 -0.327633  0.056522  0.033139  0.000000      0.425495     8
# 19894  0.105615  0.152881 -0.025292  0.021130  0.000000      0.227690     8
# 19895  0.218606 -0.138794  0.026395  0.030885  0.000000      1.309215     8
# 19896  0.062221  0.150428  0.130266  0.067290  0.000000      0.028319     8
# 19897  0.122924  0.033127  0.014454  0.007312  0.004272      1.000000     8
#
# [19898 rows x 31 columns]

# %%
Missing_Data=Card_Data.isnull().sum()
Missing_Data>0
# Out:
# V1              False
# V2              False
# V3              False
# V4              False
# V5              False
# V6              False
# V7              False
# V8              False
# V9              False
# V10             False
# V11             False
# V12             False
# V13             False
# V14             False
# V15             False
# V16             False
# V17             False
# V18             False
# V19             False
# V20             False
# V21             False
# V22             False
# V23             False
# V24             False
# V25             False
# V26             False
# V27             False
# V28             False
# Class           False
# Amount_Ratio    False
# Hour            False
# dtype: bool

# %%
Card_Data.hist(bins=50, figsize=(12, 10),color='pink')
plt.suptitle("Feature Distributions", fontsize=16)
plt.subplots_adjust(hspace=0.4)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
Classes=Card_Data['Class'].value_counts()
Classes
# Out:
# Class
# 0.000000    19812
# 1.000000       85
# 0.004272        1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))

labels = Classes.index.tolist()

plt.pie(Classes, labels=labels, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7a401e0ceb50>,
#   <matplotlib.patches.Wedge at 0x7a401b8cd350>,
#   <matplotlib.patches.Wedge at 0x7a401b8cf610>],
#  [Text(-1.0998986010812577, 0.014935439045859046, '0.0'),
#   Text(1.0998962277932736, -0.015109205344013926, '1.0'),
#   Text(1.0999999863291314, -0.00017342407846730789, '0.004272000804141328')],
#  [Text(-0.5999446914988678, 0.008146603115923115, '99.57%'),
#   Text(0.5999433969781491, -0.008241384733098503, '0.43%'),
#   Text(0.5999999925431625, -9.459495189125883e-05, '0.01%')])

# %%
Bef_Scaling=[col for col in Card_Data.columns if col != 'Class']
Card_Data[Bef_Scaling].hist(bins=50,figsize=(15,15),color='#D8BFD8')
plt.tight_layout()

# %%
from sklearn.preprocessing import StandardScaler
Scale=StandardScaler()
Credit_Data=Card_Data.drop(['Class'],axis=1)
Card_Data[Bef_Scaling]=Scale.fit_transform(Credit_Data[Bef_Scaling])
Card_Data[Bef_Scaling]
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0     -0.590221 -0.206378  1.012950  0.751029 -0.122350  0.277617  0.287603
# 1      0.759910  0.015537 -0.327714  0.116727  0.156055 -0.131662  0.049675
# 2     -0.589452 -1.036194  0.581233  0.070093 -0.237586  1.282964  0.699986
# 3     -0.381994 -0.280001  0.592425 -0.777736  0.106903  0.867262  0.286116
# 4     -0.483564  0.415973  0.454235  0.085953 -0.170486  0.002284  0.551641
# ...         ...       ...       ...       ...       ...       ...       ...
# 19893 -0.070314  0.478692  0.509878  0.310622  0.131391 -0.476531  0.727655
# 19894  0.769129 -0.107135 -0.386922  0.216016 -0.050677 -0.406767  0.003051
# 19895  0.810038 -1.108330  0.038896 -1.081695 -1.322313 -0.514611 -0.875791
# 19896 -0.128980  0.508103 -0.042531 -0.356350  0.693054 -0.244917  0.603684
# 19897 -1.251636  1.464631  0.010222 -0.158576 -0.337194  0.503372 -1.106790
#
#              V8        V9       V10  ...       V21       V22       V23  \
# 0      0.056773 -0.213163  0.255242  ...  0.035785  0.665529 -0.139018
# 1      0.046678 -0.697374  0.043863  ... -0.214677 -0.772054  0.267703
# 2      0.167391 -1.682065  0.351062  ...  0.357276  1.440140  1.819828
# 3      0.263740 -1.582261  0.135725  ... -0.072858  0.238001 -0.292376
# 4     -0.217385  0.141818  0.798335  ...  0.046501  1.481862 -0.190845
# ...         ...       ...       ...  ...       ...       ...       ...
# 19893 -0.061611 -1.064687 -0.188354  ...  0.333668  1.305612 -0.133665
# 19894  0.049748 -0.175598 -0.034915  ... -0.307143 -1.313796  0.323618
# 19895  0.007536 -1.842654  1.484097  ...  0.107072  0.641525 -0.013481
# 19896 -0.046232 -0.716152 -0.149540  ... -0.358438 -1.185150 -0.023197
# 19897 -5.672863  0.596934  1.000822  ...  0.000000  0.000000  0.000000
#
#                 V24           V25       V26           V27           V28  \
# 0      9.515388e-02  1.283036e-02 -0.419097  3.030776e-01 -1.160788e-01
# 1     -5.929531e-01  1.010991e-01  0.174937 -5.963963e-02  3.033341e-02
# 2     -1.184063e+00 -1.029506e+00 -0.324774 -1.776340e-01 -2.744469e-01
# 3     -2.006687e+00  1.198329e+00 -0.480977  1.228264e-01  2.215821e-01
# 4      2.209069e-01 -7.515865e-01  0.884736  5.215705e-01  8.505548e-01
# ...             ...           ...       ...           ...           ...
# 19893  1.050599e+00  7.863594e-03 -0.680311  1.070474e-01  1.056944e-01
# 19894 -6.790729e-01 -3.954935e-02  0.225828 -1.011408e-01  5.654758e-02
# 19895  8.542371e-01  2.186243e-01 -0.324204  3.038396e-02  9.646986e-02
# 19896 -1.812576e+00 -1.387018e-01  0.221202  2.947006e-01  2.454482e-01
# 19897 -2.934489e-18 -3.170960e-17  0.000000  4.414253e-18 -3.549530e-18
#
#        Amount_Ratio      Hour
# 0          0.386402 -1.330931
# 1         -0.329096 -1.330931
# 2          1.501747 -1.330931
# 3          0.259206 -1.330931
# 4         -0.001369 -1.330931
# ...             ...       ...
# 19893     -0.196593  1.420572
# 19894     -0.264281  1.420572
# 19895      0.105812  1.420572
# 19896     -0.332505  1.420572
# 19897      0.000000  1.420572
#
# [19898 rows x 30 columns]

# %%
Aft_Scaling=[col for col in Card_Data.columns if col != 'Class']
Card_Data[Aft_Scaling].hist(bins=50,figsize=(15,15),color='#FF007F')
plt.tight_layout()

# %%
print("Before Undersampling :")
print(Card_Data['Class'].value_counts())

Card_Data_majority = Card_Data[Card_Data['Class'] == 0]
CD_minority = Card_Data[Card_Data['Class'] == 1]

CD_majority_sampled = CD_minority.sample(n=len(CD_minority), random_state=42)

CD_balanced_undersample = pd.concat([CD_majority_sampled, CD_minority])

df_balanced_undersample = CD_balanced_undersample.sample(frac=1, random_state=42).reset_index(drop=True)

print("After Undersampling:\n")
print(df_balanced_undersample['Class'].value_counts())
# Out:
# Before Undersampling :
# Class
# 0.000000    19812
# 1.000000       85
# 0.004272        1
# Name: count, dtype: int64
# After Undersampling:
#
# Class
# 1.0    170
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
scatter = plt.scatter(
    df_balanced_undersample.iloc[:, 0],
    df_balanced_undersample.iloc[:, 1],
    c=df_balanced_undersample['Class'],
    cmap='spring',
    alpha=0.8
)
plt.title("Before PCA of Credit Card Transactions")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
cbar = plt.colorbar(scatter)
cbar.set_label("Class")
plt.show()

# %%
from sklearn.decomposition import PCA

pca_card=PCA(n_components=24)
Card_Data_pca=pca_card.fit_transform(df_balanced_undersample)
Card_Data_pca = pd.DataFrame(Card_Data_pca)
Card_Data_pca.head()
# Out:
#           0          1          2         3         4         5         6   \
# 0 -12.233689  -6.734421   4.229037  6.707290 -5.646951 -0.405788 -0.532413
# 1 -10.811320 -12.679968 -38.115377  8.694730  4.971648  0.515417 -1.671467
# 2  -5.658385 -12.280629  -0.033113 -8.448978 -0.125930  2.544643 -0.574520
# 3  -5.658385 -12.280629  -0.033113 -8.448978 -0.125930  2.544643 -0.574520
# 4 -12.689071   2.590085  -0.224856 -2.627595  1.408833  0.492481  0.885717
#
#          7         8         9   ...        14        15        16        17  \
# 0 -0.109074  0.275392 -0.345943  ... -0.019197  0.069269 -0.196246  0.064966
# 1 -0.469138 -0.364640 -0.779657  ...  0.045172 -0.249250  0.017689 -0.005329
# 2 -0.643867  0.214058 -0.075870  ...  0.366958  0.111347 -0.110464 -0.186110
# 3 -0.643867  0.214058 -0.075870  ...  0.366958  0.111347 -0.110464 -0.186110
# 4 -0.738430 -0.672490  0.548607  ... -0.028877  0.030234  0.169533 -0.164695
#
#          18        19        20        21        22        23
# 0 -0.058298 -0.059901 -0.112083  0.049005  0.001977  0.417920
# 1  0.096888  0.009135 -0.060257 -0.128866  0.038973  0.154909
# 2  0.135057  0.113687 -0.090886  0.297594  0.156885  0.080241
# 3  0.135057  0.113687 -0.090886  0.297594  0.156885  0.080241
# 4  0.041844 -0.090086  0.396742 -0.325872 -0.102333  0.043629
#
# [5 rows x 24 columns]

# %%
plt.figure(figsize=(8, 8))
scatter = plt.scatter(
    Card_Data_pca.iloc[:, 0],
    Card_Data_pca.iloc[:, 1],
    c=df_balanced_undersample['Class'],
    alpha=0.8
)
plt.title("After PCA of Credit Card Transactions")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
cbar = plt.colorbar(scatter)
cbar.set_label("Class")
plt.show()

# %%
X_meaned = Card_Data - np.mean(Card_Data, axis=0)
X_std = X_meaned / np.std(X_meaned, axis=0)

cov_matrix = np.cov(X_std, rowvar=False)

eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

sorted_index = np.argsort(eigenvalues)[::-1]
sorted_eigenvalues = eigenvalues[sorted_index]

explained_variance_ratio = sorted_eigenvalues / np.sum(sorted_eigenvalues)

cumulative_explained_variance = np.cumsum(explained_variance_ratio)

for i, (var, cum_var) in enumerate(zip(explained_variance_ratio, cumulative_explained_variance), start=1):
    print(f"PC{i}: Explained Variance Ratio = {var:.4f}, Cumulative = {cum_var:.4f}")
# Out:
# PC1: Explained Variance Ratio = 0.1375, Cumulative = 0.1375
# PC2: Explained Variance Ratio = 0.0729, Cumulative = 0.2104
# PC3: Explained Variance Ratio = 0.0574, Cumulative = 0.2677
# PC4: Explained Variance Ratio = 0.0488, Cumulative = 0.3165
# PC5: Explained Variance Ratio = 0.0450, Cumulative = 0.3616
# PC6: Explained Variance Ratio = 0.0443, Cumulative = 0.4059
# PC7: Explained Variance Ratio = 0.0397, Cumulative = 0.4456
# PC8: Explained Variance Ratio = 0.0372, Cumulative = 0.4828
# PC9: Explained Variance Ratio = 0.0360, Cumulative = 0.5188
# PC10: Explained Variance Ratio = 0.0346, Cumulative = 0.5534
# PC11: Explained Variance Ratio = 0.0340, Cumulative = 0.5874
# PC12: Explained Variance Ratio = 0.0328, Cumulative = 0.6202
# PC13: Explained Variance Ratio = 0.0317, Cumulative = 0.6520
# PC14: Explained Variance Ratio = 0.0307, Cumulative = 0.6826
# PC15: Explained Variance Ratio = 0.0288, Cumulative = 0.7114
# PC16: Explained Variance Ratio = 0.0280, Cumulative = 0.7394
# PC17: Explained Variance Ratio = 0.0273, Cumulative = 0.7668
# PC18: Explained Variance Ratio = 0.0268, Cumulative = 0.7936
# PC19: Explained Variance Ratio = 0.0244, Cumulative = 0.8180
# PC20: Explained Variance Ratio = 0.0240, Cumulative = 0.8420
# PC21: Explained Variance Ratio = 0.0223, Cumulative = 0.8642
# PC22: Explained Variance Ratio = 0.0216, Cumulative = 0.8858
# PC23: Explained Variance Ratio = 0.0200, Cumulative = 0.9059
# PC24: Explained Variance Ratio = 0.0180, Cumulative = 0.9239
# PC25: Explained Variance Ratio = 0.0167, Cumulative = 0.9406
# PC26: Explained Variance Ratio = 0.0161, Cumulative = 0.9567
# PC27: Explained Variance Ratio = 0.0140, Cumulative = 0.9706
# PC28: Explained Variance Ratio = 0.0118, Cumulative = 0.9824
# PC29: Explained Variance Ratio = 0.0108, Cumulative = 0.9932
# PC30: Explained Variance Ratio = 0.0065, Cumulative = 0.9997
# PC31: Explained Variance Ratio = 0.0003, Cumulative = 1.0000

# %%
threshold = 0.90
num_components = np.argmax(cumulative_explained_variance >= threshold) + 1

print(f"Number of components to preserve {threshold*100}% variance: {num_components}")
# Out:
# Number of components to preserve 90.0% variance: 23

# %%
threshold = 0.95
num_components = np.argmax(cumulative_explained_variance >= threshold) + 1

print(f"Number of components to preserve {threshold*100}% variance: {num_components}")
# Out:
# Number of components to preserve 95.0% variance: 26

# %%
plt.figure(figsize=(8,6))
plt.scatter(Card_Data_pca.iloc[:, 0], Card_Data_pca.iloc[:, 1], c='red', label='Class 0', alpha=0.7)
plt.scatter(Card_Data_pca.iloc[:, 0], Card_Data_pca.iloc[:, 1], c='skyblue', label='Class 1', alpha=0.7)

plt.xlabel("First principal component")
plt.ylabel("Second principal component")
plt.title("2D PCA Scatter Plot")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.manifold import TSNE
tsne = TSNE(perplexity=5, n_iter=300, random_state=42)
Card_tsne = tsne.fit_transform(Card_Data_pca)

Card_tsne
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# array([[-20.374882  , -10.864027  ],
#        [ -9.664982  ,  -9.289427  ],
#        [ -7.6258273 ,  -2.658721  ],
#        [ -7.560536  ,  -2.6224852 ],
#        [ -7.8279715 , -17.80526   ],
#        [-11.186038  ,  17.455599  ],
#        [  9.469094  ,  -2.5334198 ],
#        [ -3.1782014 , -18.515993  ],
#        [  3.3304398 ,  19.052467  ],
#        [-16.49351   ,  -2.1773531 ],
#        [-20.257103  , -10.91134   ],
#        [  1.0222317 ,  10.84037   ],
#        [-18.248682  ,  -4.132289  ],
#        [  3.6507218 ,   4.50489   ],
#        [ -7.8279715 , -17.80526   ],
#        [  1.5878203 ,  12.644935  ],
#        [  9.691834  ,   8.197482  ],
#        [ -1.8700274 ,   6.1444187 ],
#        [ -1.503212  ,   2.9214854 ],
#        [ 19.925018  ,  12.197163  ],
#        [-17.498016  ,  -2.7178113 ],
#        [-11.233435  ,   2.156883  ],
#        [  9.129022  ,   4.6846523 ],
#        [-10.171295  ,   5.656883  ],
#        [-17.614462  ,   6.9887934 ],
#        [  1.1552888 , -13.466254  ],
#        [  2.3629658 ,  -4.8995876 ],
#        [  2.6491044 ,  16.441048  ],
#        [ -1.7984841 ,  11.587822  ],
#        [ 21.546911  ,   9.694027  ],
#        [ -4.7886515 , -18.694363  ],
#        [ -8.214391  ,  -2.1290648 ],
#        [  0.39805955, -15.109677  ],
#        [ 18.134403  ,  -1.614769  ],
#        [ -1.8625201 , -17.829004  ],
#        [-20.015553  ,  -9.364342  ],
#        [  2.551295  , -10.090001  ],
#        [ 16.862337  ,  -1.3795254 ],
#        [-18.970194  ,  -5.8269243 ],
#        [  2.177813  ,  -5.0092373 ],
#        [ 18.599781  ,   4.443425  ],
#        [ 19.658972  ,  -6.434279  ],
#        [ 18.598228  ,   4.4337583 ],
#        [ -4.7978363 , -18.70764   ],
#        [-19.54692   ,  -7.5853586 ],
#        [  1.2135375 ,  17.515583  ],
#        [ -8.342136  , -20.560678  ],
#        [ 12.044858  , -12.633117  ],
#        [ 11.161798  , -16.412418  ],
#        [ 10.835208  , -14.163093  ],
#        [ 20.657848  ,   8.277146  ],
#        [ -9.527648  ,  14.581559  ],
#        [  6.7658987 ,   8.473179  ],
#        [-13.514429  ,  -4.064284  ],
#        [-12.377149  ,  19.91137   ],
#        [-16.841986  ,  -1.8255756 ],
#        [  8.692004  ,   9.686095  ],
#        [-12.567107  ,  -6.4650235 ],
#        [-11.943537  ,  18.850775  ],
#        [ -3.1782014 , -18.515993  ],
#        [  2.780983  ,  -6.479056  ],
#        [  2.695192  ,  16.482162  ],
#        [  1.2177892 ,  17.518534  ],
#        [ -8.710138  , -17.96572   ],
#        [ 20.657848  ,   8.277146  ],
#        [  2.8523793 ,   5.1055145 ],
#        [-10.171295  ,   5.656883  ],
#        [  8.692004  ,   9.686095  ],
#        [ 10.305306  , -13.3116665 ],
#        [ 21.546911  ,   9.694027  ],
#        [ -0.6256143 ,   1.5053562 ],
#        [-11.179449  ,  17.452888  ],
#        [ 10.391297  , -13.272951  ],
#        [  2.8523793 ,   5.1055145 ],
#        [ -2.78126   ,   9.697249  ],
#        [ 11.504383  ,   9.99947   ],
#        [-17.616356  ,   6.9448094 ],
#        [  0.28801575,   2.0857184 ],
#        [-20.015553  ,  -9.364342  ],
#        [-11.233435  ,   2.156883  ],
#        [ -0.56805927, -16.63853   ],
#        [-18.738806  ,   7.0164866 ],
#        [  3.6507218 ,   4.50489   ],
#        [ 12.514863  , -10.872317  ],
#        [ -8.712547  ,  13.219078  ],
#        [-18.970194  ,  -5.8269243 ],
#        [-19.744812  ,   6.58629   ],
#        [  9.701498  ,   8.182661  ],
#        [  9.464184  ,  -8.789236  ],
#        [ -7.8487062 ,  -1.9016447 ],
#        [-12.377149  ,  19.91137   ],
#        [ -8.330323  , -20.506409  ],
#        [  1.8475505 , -11.766187  ],
#        [ -6.4476523 ,  -5.1844525 ],
#        [ -0.77424836,  -0.58372384],
#        [  9.486697  ,  -8.805567  ],
#        [  0.39805955, -15.109677  ],
#        [ -8.712547  ,  13.219078  ],
#        [ 10.835208  , -14.163093  ],
#        [-13.4811325 ,  -4.0987935 ],
#        [ -6.4476523 ,  -5.1844525 ],
#        [ 21.314978  ,  -0.22487189],
#        [  2.4943128 ,  19.26071   ],
#        [-20.589636  , -12.06387   ],
#        [-14.680427  , -11.208571  ],
#        [  9.321093  ,  -1.6071732 ],
#        [-10.908095  ,   5.016746  ],
#        [ 19.549774  ,  12.655618  ],
#        [  1.7370669 ,  -3.9052432 ],
#        [-10.689013  ,   4.025107  ],
#        [  2.96424   ,  -8.310851  ],
#        [  2.935154  ,  18.760595  ],
#        [ 20.355927  ,  12.55802   ],
#        [ 18.59396   ,  -0.17058344],
#        [ 16.869846  ,  -1.3816291 ],
#        [ 11.966829  ,   9.469623  ],
#        [ -2.9087946 ,   1.6353743 ],
#        [  1.0032405 ,  10.841627  ],
#        [  2.89122   ,  -8.315998  ],
#        [-19.744812  ,   6.58629   ],
#        [ 19.89696   ,   5.760214  ],
#        [ 20.385235  ,  -6.730513  ],
#        [  1.8783836 , -11.794782  ],
#        [  2.551295  , -10.090001  ],
#        [ 11.216265  ,  -2.3851752 ],
#        [ 11.219193  ,  -2.386242  ],
#        [-10.280753  ,  15.883461  ],
#        [-18.651926  ,   6.5410614 ],
#        [  1.749464  ,  -3.8834798 ],
#        [ 18.136974  ,  -1.611676  ],
#        [ 12.514863  , -10.872317  ],
#        [-14.680427  , -11.208571  ],
#        [-10.280753  ,  15.883461  ],
#        [ 19.558914  ,  -6.702667  ],
#        [ -1.8625201 , -17.829004  ],
#        [-17.498016  ,  -2.7178113 ],
#        [ 12.044858  , -12.633117  ],
#        [  2.7924204 ,  -6.523528  ],
#        [  9.469094  ,  -2.5334198 ],
#        [ 21.314978  ,  -0.22487189],
#        [ 19.971012  ,  12.99795   ],
#        [ -9.527648  ,  14.581559  ],
#        [  9.321093  ,  -1.6071732 ],
#        [ -8.466361  , -18.328302  ],
#        [ 19.88965   ,   5.7144012 ],
#        [ -2.9285324 ,   1.6538136 ],
#        [ -0.6256143 ,   1.5053562 ],
#        [ 11.161798  , -16.412418  ],
#        [-11.943537  ,  18.850775  ],
#        [ -9.664982  ,  -9.289427  ],
#        [  2.9201133 ,  19.572065  ],
#        [ -2.78126   ,   9.697249  ],
#        [  1.5878203 ,  12.644935  ],
#        [-18.248682  ,  -4.132289  ],
#        [ -0.56805927, -16.63853   ],
#        [-12.563544  ,  -6.4687777 ],
#        [  1.1213332 , -13.455175  ],
#        [ 11.635971  ,   9.111764  ],
#        [ 20.385235  ,  -6.730513  ],
#        [  0.28801575,   2.0857184 ],
#        [ -1.763141  ,  11.583787  ],
#        [-19.54692   ,  -7.5853586 ],
#        [-10.689013  ,   4.025107  ],
#        [  9.129022  ,   4.6846523 ],
#        [  6.7662635 ,   8.516896  ],
#        [-10.908095  ,   5.016746  ],
#        [ -1.5594243 ,   2.9103343 ],
#        [-20.96827   , -11.870889  ],
#        [ 18.591682  ,  -0.17902915],
#        [ 11.184686  ,   9.674138  ]], dtype=float32)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(Card_Data_pca)

# %%
plt.figure(figsize=(8,6))
scatter = plt.scatter(Card_Data_pca.iloc[:, 0], Card_Data_pca.iloc[:, 1],
                      c=clusters, cmap='coolwarm', alpha=0.7)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('Clusters formed after PCA and K-means')
plt.colorbar(scatter, label='Cluster')
plt.show()

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(Card_tsne[:, 0], Card_tsne[:, 1],
                      c=df_balanced_undersample['Class'], cmap='coolwarm', alpha=0.6)
plt.colorbar(scatter, label='Class')
plt.xlabel("t-SNE feature 1")
plt.ylabel("t-SNE feature 2")
plt.title("t-SNE Visualization of Credit Card Transactions")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(Card_tsne[:, 0], Card_tsne[:, 1], c=clusters, cmap='coolwarm', s=10, alpha=0.7)
plt.title("t-SNE After Clustering (KMeans)")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.grid(True)
plt.colorbar(label="Cluster")
plt.show()

# %% [markdown]
# ##2. Clustering Analysis##

# %%
from sklearn.cluster import KMeans

Inertia_Value = []
for i in range(2,20):
  kmean=KMeans(n_clusters=i,random_state=42)
  kmean.fit(Card_Data_pca)
  Inertia_Value.append(kmean.inertia_)
  print(f"Inertia for {i} clusters: {kmean.inertia_}")
# Out:
# Inertia for 2 clusters: 24208.60643756128
# Inertia for 3 clusters: 20741.6871366869
# Inertia for 4 clusters: 11802.877852856565
# Inertia for 5 clusters: 10960.823159499458
# Inertia for 6 clusters: 8923.26761019286
# Inertia for 7 clusters: 7752.2155309391055
# Inertia for 8 clusters: 5336.977380675576
# Inertia for 9 clusters: 4791.598888829879
# Inertia for 10 clusters: 4339.922121396267
# Inertia for 11 clusters: 3875.477117585559
# Inertia for 12 clusters: 3489.8418318821828
# Inertia for 13 clusters: 3048.981203000142
# Inertia for 14 clusters: 2754.9585719321517
# Inertia for 15 clusters: 2588.2089118693034
# Inertia for 16 clusters: 2375.3795216011395
# Inertia for 17 clusters: 2067.680995839156
# Inertia for 18 clusters: 1702.9964410194261
# Inertia for 19 clusters: 1584.4677356094244

# %%
plt.figure(figsize=(12,6))
plt.plot(range(2,20),Inertia_Value,linewidth=2,color="skyblue",marker="8")
plt.xlabel("K Value")
plt.xticks(np.arange(2,20,1))
plt.ylabel("Inertia Value")
# Out:
# Text(0, 0.5, 'Inertia Value')

# %%
from sklearn.metrics import silhouette_score

labels = kmean.fit_predict(Card_Data_pca)

score = silhouette_score(Card_Data_pca, labels)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.5160170412583095

# %%
silhouette_scores = []
k_values = range(2, 20)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(Card_Data_pca)
    score = silhouette_score(Card_Data_pca, labels)
    silhouette_scores.append(score)
    print(f"Silhouette Score for k={k}: {score:.4f}")

plt.plot(k_values, silhouette_scores, marker='o')
plt.xlabel('Number of clusters k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for different k values')
plt.show()
# Out:
# Silhouette Score for k=2: 0.5019
# Silhouette Score for k=3: 0.5203
# Silhouette Score for k=4: 0.5739
# Silhouette Score for k=5: 0.5173
# Silhouette Score for k=6: 0.3915
# Silhouette Score for k=7: 0.4122
# Silhouette Score for k=8: 0.4641
# Silhouette Score for k=9: 0.4555
# Silhouette Score for k=10: 0.4706
# Silhouette Score for k=11: 0.4904
# Silhouette Score for k=12: 0.4872
# Silhouette Score for k=13: 0.4845
# Silhouette Score for k=14: 0.4871
# Silhouette Score for k=15: 0.4740
# Silhouette Score for k=16: 0.4622
# Silhouette Score for k=17: 0.4850
# Silhouette Score for k=18: 0.5030
# Silhouette Score for k=19: 0.5160
